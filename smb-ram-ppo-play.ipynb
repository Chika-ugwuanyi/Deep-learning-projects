# %% [markdown]
# # Load and test a pre-trained model

# %%
#pip install gym
#!pip install gym-super-mario-bros
#!pip install gymnasium
#!pip install nes-py
#!pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Using cached stable_baselines3-2.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting gymnasium<1.3.0,>=0.29.1 (from stable-baselines3)
#   Using cached gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\anaconda\lib\site-packages (from stable-baselines3) (2.3.5)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\anaconda\lib\site-packages (from stable-baselines3) (2.11.0)
# Requirement already satisfied: cloudpickle in c:\users\anaconda\lib\site-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in c:\users\anaconda\lib\site-packages (from stable-baselines3) (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\anaconda\lib\site-packages (from stable-baselines3) (3.10.6)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\anaconda\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\anaconda\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.6)
# Requirement already satisfied: filelock in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools<82 in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anaconda\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anaconda\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anaconda\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anaconda\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Using cached stable_baselines3-2.8.0-py3-none-any.whl (187 kB)
# Using cached gymnasium-1.2.3-py3-none-any.whl (952 kB)
# Installing collected packages: gymnasium, stable-baselines3
#
#   Attempting uninstall: gymnasium
#
#     Found existing installation: gymnasium 1.3.0
#
#     Uninstalling gymnasium-1.3.0:
#
#       Successfully uninstalled gymnasium-1.3.0
#
#    ---------------------------------------- 0/2 [gymnasium]
#    ---------------------------------------- 0/2 [gymnasium]
#    ---------------------------------------- 0/2 [gymnasium]
#    ---------------------------------------- 0/2 [gymnasium]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    ---------------------------------------- 2/2 [stable-baselines3]
#
# Successfully installed gymnasium-1.2.3 stable-baselines3-2.8.0

# %%
# import dependencies
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv
from stable_baselines3.common.evaluation import evaluate_policy

import os

from gym_utils import SMBRamWrapper, load_smb_env, SMB

# %%
# Select a pre-trained model
MODEL_DIR = './models'

# obs = 4 frames
crop_dim = [0, 16, 0, 13]
n_stack = 4
n_skip = 4
MODEL_NAME = 'pre-trained-1'

# obs = 1 frames
#crop_dim = [0, 16, 0, 13]
#n_stack = 1
#n_skip = 1
#MODEL_NAME = 'pre-trained-2'


# obs = 2 frames
#crop_dim = [0, 16, 0, 13]
#n_stack = 2
#n_skip = 4
#MODEL_NAME = 'pre-trained-3'

# %%
# load env and model
env_wrap = load_smb_env('SuperMarioBros-1-1-v3', crop_dim, n_stack, n_skip)
model = PPO.load(os.path.join(MODEL_DIR, MODEL_NAME), env=env_wrap)
smb = SMB(env_wrap, model)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[13], line 2
#       1 # load env and model
# ----> 2 env_wrap = load_smb_env('SuperMarioBros-1-1-v3', crop_dim, n_stack, n_skip)
#       3 model = PPO.load(os.path.join(MODEL_DIR, MODEL_NAME), env=env_wrap)
#       4 smb = SMB(env_wrap, model)
#
# File ~\OneDrive\Desktop\python\machine learning\super-mario-bros\super-mario-bros\gym_utils.py:88, in load_smb_env(name, crop_dim, n_stack, n_skip)
#      84 def load_smb_env(name='SuperMarioBros-1-1-v0', crop_dim=[0,16,0,13], n_stack=2, n_skip=4):
#      85     '''
#      86     Wrapper function for loading and processing smb env
#      87     '''
# ---> 88     env = gym_super_mario_bros.make(name)
#      89     env = JoypadSpace(env, SIMPLE_MOVEMENT)
#      90     env_wrap = SMBRamWrapper(env, crop_dim, n_stack=n_stack, n_skip=n_skip)
#
# File C:\Users\anaconda\Lib\site-packages\gym\envs\registration.py:640, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     633     logger.warn(
#     634         f"Expects the environment metadata render_modes to be a Sequence (tuple or list), actual type: {type(render_modes)}"
#     635     )
#     637 # Apply the `HumanRendering` wrapper, if the mode=="human" but "human" not in render_modes
#     638 if (
#     639     mode == "human"
# --> 640     and "human" not in render_modes
#     641     and ("single_rgb_array" in render_modes or "rgb_array" in render_modes)
#     642 ):
#     643     logger.warn(
#     644         "You are trying to use 'human' rendering for an environment that doesn't natively support it. "
#     645         "The HumanRendering wrapper is being applied to your environment."
#     646     )
#     647     apply_human_rendering = True
#
# File C:\Users\anaconda\Lib\site-packages\gym_super_mario_bros\smb_env.py:52, in SuperMarioBrosEnv.__init__(self, rom_mode, lost_levels, target)
#      50 rom = rom_path(lost_levels, rom_mode)
#      51 # initialize the super object with the ROM path
# ---> 52 super(SuperMarioBrosEnv, self).__init__(rom)
#      53 # set the target world, stage, and area variables
#      54 target = decode_target(target, lost_levels)
#
# File C:\Users\anaconda\Lib\site-packages\nes_py\nes_env.py:126, in NESEnv.__init__(self, rom_path)
#     124     raise ValueError('ROM has trainer. trainer is not supported.')
#     125 # try to read the PRG ROM and raise a value error if it fails
# --> 126 _ = rom.prg_rom
#     127 # try to read the CHR ROM and raise a value error if it fails
#     128 _ = rom.chr_rom
#
# File C:\Users\anaconda\Lib\site-packages\nes_py\_rom.py:204, in ROM.prg_rom(self)
#     202 """Return the PRG ROM of the ROM file."""
#     203 try:
# --> 204     return self.raw_data[self.prg_rom_start:self.prg_rom_stop]
#     205 except IndexError:
#     206     raise ValueError('failed to read PRG-ROM on ROM.')
#
# File C:\Users\anaconda\Lib\site-packages\nes_py\_rom.py:198, in ROM.prg_rom_stop(self)
#     195 @property
#     196 def prg_rom_stop(self):
#     197     """The exclusive stopping index of the PRG ROM."""
# --> 198     return self.prg_rom_start + self.prg_rom_size * 2**10
#
# OverflowError: Python integer 1024 out of bounds for uint8

# %%
smb.play(episodes=1, deterministic=True, render=True, return_eval=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 smb.play(episodes=1, deterministic=True, render=True, return_eval=True)
#
# NameError: name 'smb' is not defined
